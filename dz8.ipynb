# %% [markdown]
# <a href="https://colab.research.google.com/github/Oksana57/Exampl/blob/main/dz8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# На сайте запущен А/В тест с целью увеличить доход. В приложенном excel файле вы найдете сырые данные по результатам эксперимента – user_id, тип выборки variant_name и доход принесенный пользователем revenue.
# Проанализируйте результаты эксперимента и напишите свои рекомендации менеджеру.

# %%
from scipy import stats
import numpy as np

import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_excel('/content/AB_Test_Results (2).xlsx')

# %%
data.head(5)
# Out:
#    USER_ID VARIANT_NAME  REVENUE
# 0      737      variant      0.0
# 1     2423      control      0.0
# 2     9411      control      0.0
# 3     7311      control      0.0
# 4     6174      variant      0.0

# %%
data.info
# Out:
# <bound method DataFrame.info of       USER_ID VARIANT_NAME  REVENUE
# 0         737      variant      0.0
# 1        2423      control      0.0
# 2        9411      control      0.0
# 3        7311      control      0.0
# 4        6174      variant      0.0
# ...       ...          ...      ...
# 9995     1981      control      0.0
# 9996      502      variant      0.0
# 9997     9214      variant      0.0
# 9998     7741      control      0.0
# 9999     9468      control      0.0
#
# [10000 rows x 3 columns]>

# %%
data.describe()
# Out:
#             USER_ID       REVENUE
# count  10000.000000  10000.000000
# mean    4981.080200      0.099447
# std     2890.590115      2.318529
# min        2.000000      0.000000
# 25%     2468.750000      0.000000
# 50%     4962.000000      0.000000
# 75%     7511.500000      0.000000
# max    10000.000000    196.010000

# %%
# убираем неуникальные строки по id
data = data.drop_duplicates()

# %%
data.describe()
# Out:
#             USER_ID      REVENUE
# count   7933.000000  7933.000000
# mean    4976.885289     0.125359
# std     2892.278447     2.602527
# min        2.000000     0.000000
# 25%     2460.000000     0.000000
# 50%     4965.000000     0.000000
# 75%     7505.000000     0.000000
# max    10000.000000   196.010000

# %%
group_a = data[data.VARIANT_NAME == 'control']
group_b = data[data.VARIANT_NAME == 'variant']

# %%
group_a.describe()
# Out:
#             USER_ID      REVENUE
# count   3973.000000  3973.000000
# mean    4988.320664     0.161842
# std     2895.606855     3.367815
# min        2.000000     0.000000
# 25%     2474.000000     0.000000
# 50%     4971.000000     0.000000
# 75%     7572.000000     0.000000
# max    10000.000000   196.010000

# %%
group_b.describe()
# Out:
#             USER_ID      REVENUE
# count   3960.000000  3960.000000
# mean    4965.412374     0.088755
# std     2889.255440     1.479239
# min        3.000000     0.000000
# 25%     2442.750000     0.000000
# 50%     4958.500000     0.000000
# 75%     7425.000000     0.000000
# max    10000.000000    58.630000

# %%
stats.mannwhitneyu(x = group_a.REVENUE.values, y = group_b.REVENUE.values)
# Out:
# MannwhitneyuResult(statistic=7882388.0, pvalue=0.5128877468183902)

# %%
C_mean = group_a.REVENUE.values.mean()
T_mean = group_b.REVENUE.values.mean()
C_std = group_a.REVENUE.values.std()
T_std = group_b.REVENUE.values.std()

# %%
n =  len(group_a.REVENUE.values)
S = np.sqrt((T_std**2 + C_std **2)/ 2)
f =float((T_mean-C_mean)/ S)

# %%
from statsmodels.stats.power import TTestIndPower

# %%
alpha = 0.05

analysis = TTestIndPower()
result = analysis.solve_power(f, power=None,
nobs1=n, ratio=1.0, alpha=alpha)

result
# Out:
# 0.24027221868963883

# %% [markdown]
# По резульатам тестирования метрики ARPU разницы в доходности при изменении введенном в группе В значимых различий не обнаружено(pvalue > alpha). Хотя выборка невелика сделали тест на мощность тесирования менее 30%. Соответвтенно для уточнения результата можно провести дополнительное тестирование
